# %%
import numpy as np
import cv2
import imutils
import os 
import joblib
import matplotlib.pyplot as plt
# %matplotlib inline

from imutils.object_detection import non_max_suppression
from skimage.transform import pyramid_gaussian
from skimage.feature import hog, local_binary_pattern
from skimage.color import rgb2gray

import warnings
warnings.filterwarnings('ignore')

# %%
model_path = r'D:\UGM\Semester 4\Computer Vision and Image Analysis\Final Project\model'
winname = 'Window'

clf = joblib.load(os.path.join(model_path, 'svm_tuned.sav'))

# %%
def sliding_window(image, window_size, step_size):
    for y in range(0, image.shape[0], step_size[1]):
        for x in range(0, image.shape[1], step_size[0]):
            yield (x, y, image[y:y + window_size[1], x:x + window_size[0]])

# %%
def detector(filename):
    image = cv2.imread(filename)
    image = imutils.resize(image, width=min(1000, image.shape[1]))
    min_window_size = (64, 64)
    step_size = (16, 16)
    downscale = 2.5

    detections = []
    scale = 0

    for img_scaled in pyramid_gaussian(image, downscale=downscale):
        if img_scaled.shape[0] < min_window_size[1] or \
           img_scaled.shape[1] < min_window_size[0]:
            break

        for (x, y, img_window) in sliding_window(img_scaled, min_window_size, step_size):
            if img_window.shape[0] != min_window_size[1] or \
               img_window.shape[1] != min_window_size[0]:
                continue
            
            if img_window.shape[2] == 3:
                img_window = cv2.resize(img_window, (128, 128), interpolation=cv2.INTER_AREA)
                cv2.namedWindow(winname)        
                cv2.moveWindow(winname, 40, 200)
                cv2.imshow(winname, img_window)
                cv2.waitKey(1)

                img_window = rgb2gray(img_window)
                hog_features, _ = hog(img_window, orientations=9, pixels_per_cell=(8, 8), 
                                    cells_per_block=(2, 2), visualize=True)
                lbp = local_binary_pattern(img_window, 24, 3, method='uniform')
                lbp_features = lbp.flatten()

                combined_features = np.concatenate((hog_features, lbp_features))
                combined_features = combined_features.reshape(1, -1)
                pred = clf.predict(combined_features)


            clone = image.copy()
            # print(pred)
            cv2.rectangle(clone, (x, y), (x + min_window_size[0], y + min_window_size[1]), (0, 255, 0), 2)
            cv2.putText(clone, 'Prediction: {}'.format(pred), (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
            cv2.imshow('Sliding Window', clone)
            # cv2.imshow('HOG', hog_features)
            cv2.imshow('LBP', lbp)
            cv2.waitKey(1)

            if pred == 1:
                print('Detection:: Location -> ({}, {}) | Scale -> {} | Confidence Score -> {}'.format(x, y, scale, clf.decision_function(combined_features)))
                if clf.decision_function(combined_features) > 0.5:
                    detections.append((int(x * (downscale**scale)), 
                                       int(y * (downscale**scale)), 
                                       clf.decision_function(combined_features), 
                                       int(min_window_size[0] * (downscale**scale)), 
                                       int(min_window_size[1] * (downscale**scale))))
            
        scale += 1
    
    clone = image.copy()

    for (x_tl, y_tl, _, w, h) in detections:
        cv2.rectangle(image, (x_tl, y_tl), (x_tl + w, y_tl + h), (0, 255, 0), thickness=2)
    
    rects = np.array([[x, y, x + w, y + h] for (x, y, _, w, h) in detections])
    sc = [score[0] for (_, _, score, _, _) in detections]
    print(sc)

    sc = np.array(sc)
    pick = non_max_suppression(rects, probs=sc, overlapThresh=0.3)

    for (startX, startY, endX, endY) in pick:
        cv2.rectangle(clone, (startX, startY), (endX, endY), (0, 255, 0), 2)

    plt.axis("off")
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title("Raw Detection before NMS")
    plt.show()

    plt.axis("off")
    plt.imshow(cv2.cvtColor(clone, cv2.COLOR_BGR2RGB))
    plt.title("Final Detections after NMS")
    plt.show()

# %%
filename = "D:/UGM/Semester 4/Computer Vision and Image Analysis/Final Project/dataset/raw/IMG_2392.jpg"
detector(filename)
# Out:
# Detection:: Location -> (0, 0) | Scale -> 0 | Confidence Score -> [1.63484886]
# Detection:: Location -> (30, 0) | Scale -> 0 | Confidence Score -> [1.15694686]
# Detection:: Location -> (60, 0) | Scale -> 0 | Confidence Score -> [1.7797868]
# Detection:: Location -> (90, 0) | Scale -> 0 | Confidence Score -> [1.32175239]
# Detection:: Location -> (120, 0) | Scale -> 0 | Confidence Score -> [1.49696441]
# Detection:: Location -> (150, 0) | Scale -> 0 | Confidence Score -> [1.10814599]
# Detection:: Location -> (180, 0) | Scale -> 0 | Confidence Score -> [1.3952721]
# Detection:: Location -> (210, 0) | Scale -> 0 | Confidence Score -> [1.26713658]
# Detection:: Location -> (240, 0) | Scale -> 0 | Confidence Score -> [1.29495272]
# Detection:: Location -> (270, 0) | Scale -> 0 | Confidence Score -> [1.52525834]
# Detection:: Location -> (300, 0) | Scale -> 0 | Confidence Score -> [1.38003961]
# Detection:: Location -> (330, 0) | Scale -> 0 | Confidence Score -> [1.28652684]
# Detection:: Location -> (360, 0) | Scale -> 0 | Confidence Score -> [1.16857811]
# Detection:: Location -> (390, 0) | Scale -> 0 | Confidence Score -> [1.65820292]
# Detection:: Location -> (420, 0) | Scale -> 0 | Confidence Score -> [1.49403958]
# Detection:: Location -> (450, 0) | Scale -> 0 | Confidence Score -> [1.37217249]
# Detection:: Location -> (480, 0) | Scale -> 0 | Confidence Score -> [1.25412054]
# Detection:: Location -> (510, 0) | Scale -> 0 | Confidence Score -> [1.0359396]
# Detection:: Location -> (540, 0) | Scale -> 0 | Confidence Score -> [1.16338104]
# Detection:: Location -> (570, 0) | Scale -> 0 | Confidence Score -> [1.36774954]
# Detection:: Location -> (600, 0) | Scale -> 0 | Confidence Score -> [1.33756382]
# Detection:: Location -> (630, 0) | Scale -> 0 | Confidence Score -> [1.39248729]
# Detection:: Location -> (660, 0) | Scale -> 0 | Confidence Score -> [1.41348345]
# Detection:: Location -> (690, 0) | Scale -> 0 | Confidence Score -> [1.45240083]
# Detection:: Location -> (720, 0) | Scale -> 0 | Confidence Score -> [1.49304327]
# Detection:: Location -> (750, 0) | Scale -> 0 | Confidence Score -> [1.23471658]
# Detection:: Location -> (780, 0) | Scale -> 0 | Confidence Score -> [1.43618358]
# Detection:: Location -> (810, 0) | Scale -> 0 | Confidence Score -> [1.34836325]
# Detection:: Location -> (840, 0) | Scale -> 0 | Confidence Score -> [1.41621315]
# Detection:: Location -> (870, 0) | Scale -> 0 | Confidence Score -> [1.45179452]
# Detection:: Location -> (0, 30) | Scale -> 0 | Confidence Score -> [1.5736918]
# Detection:: Location -> (30, 30) | Scale -> 0 | Confidence Score -> [1.75243669]
# Detection:: Location -> (60, 30) | Scale -> 0 | Confidence Score -> [1.80549512]
# Detection:: Location -> (90, 30) | Scale -> 0 | Confidence Score -> [1.83523851]
# Detection:: Location -> (120, 30) | Scale -> 0 | Confidence Score -> [1.6515744]
# Detection:: Location -> (150, 30) | Scale -> 0 | Confidence Score -> [1.72592369]
# Detection:: Location -> (180, 30) | Scale -> 0 | Confidence Score -> [1.40854708]
# Detection:: Location -> (210, 30) | Scale -> 0 | Confidence Score -> [1.64138248]
# Detection:: Location -> (240, 30) | Scale -> 0 | Confidence Score -> [1.62774555]
# Detection:: Location -> (270, 30) | Scale -> 0 | Confidence Score -> [1.38615734]
# Detection:: Location -> (300, 30) | Scale -> 0 | Confidence Score -> [1.28560309]
# Detection:: Location -> (330, 30) | Scale -> 0 | Confidence Score -> [1.50103541]
# Detection:: Location -> (360, 30) | Scale -> 0 | Confidence Score -> [1.50489533]
# Detection:: Location -> (390, 30) | Scale -> 0 | Confidence Score -> [1.58831926]
# Detection:: Location -> (420, 30) | Scale -> 0 | Confidence Score -> [1.76210211]
# Detection:: Location -> (450, 30) | Scale -> 0 | Confidence Score -> [1.38492039]
# Detection:: Location -> (480, 30) | Scale -> 0 | Confidence Score -> [1.05978841]
# Detection:: Location -> (510, 30) | Scale -> 0 | Confidence Score -> [1.21087366]
# Detection:: Location -> (540, 30) | Scale -> 0 | Confidence Score -> [1.41595311]
# Detection:: Location -> (570, 30) | Scale -> 0 | Confidence Score -> [1.65274798]
# Detection:: Location -> (600, 30) | Scale -> 0 | Confidence Score -> [1.63329114]
# Detection:: Location -> (630, 30) | Scale -> 0 | Confidence Score -> [1.62030306]
# Detection:: Location -> (660, 30) | Scale -> 0 | Confidence Score -> [1.52618636]
# Detection:: Location -> (690, 30) | Scale -> 0 | Confidence Score -> [1.69472187]
# Detection:: Location -> (720, 30) | Scale -> 0 | Confidence Score -> [1.4145313]
# Detection:: Location -> (750, 30) | Scale -> 0 | Confidence Score -> [1.55225957]
# Detection:: Location -> (780, 30) | Scale -> 0 | Confidence Score -> [1.68560697]
# Detection:: Location -> (810, 30) | Scale -> 0 | Confidence Score -> [1.40366723]
# Detection:: Location -> (840, 30) | Scale -> 0 | Confidence Score -> [1.477766]
# Detection:: Location -> (870, 30) | Scale -> 0 | Confidence Score -> [1.48859164]
# Detection:: Location -> (0, 60) | Scale -> 0 | Confidence Score -> [1.42895594]
# Detection:: Location -> (30, 60) | Scale -> 0 | Confidence Score -> [1.51232908]
# Detection:: Location -> (60, 60) | Scale -> 0 | Confidence Score -> [1.74809052]
# Detection:: Location -> (90, 60) | Scale -> 0 | Confidence Score -> [1.36885117]
# Detection:: Location -> (120, 60) | Scale -> 0 | Confidence Score -> [1.692285]
# Detection:: Location -> (150, 60) | Scale -> 0 | Confidence Score -> [1.45566563]
# Detection:: Location -> (180, 60) | Scale -> 0 | Confidence Score -> [1.89844496]
# Detection:: Location -> (210, 60) | Scale -> 0 | Confidence Score -> [1.53704552]
# Detection:: Location -> (240, 60) | Scale -> 0 | Confidence Score -> [1.85991492]
# Detection:: Location -> (270, 60) | Scale -> 0 | Confidence Score -> [1.37649981]
# Detection:: Location -> (300, 60) | Scale -> 0 | Confidence Score -> [1.72220248]
# Detection:: Location -> (330, 60) | Scale -> 0 | Confidence Score -> [1.81752405]
# Detection:: Location -> (360, 60) | Scale -> 0 | Confidence Score -> [1.378635]
# Detection:: Location -> (390, 60) | Scale -> 0 | Confidence Score -> [1.50789179]
# Detection:: Location -> (420, 60) | Scale -> 0 | Confidence Score -> [1.41727264]
# Detection:: Location -> (450, 60) | Scale -> 0 | Confidence Score -> [1.74383638]
# Detection:: Location -> (480, 60) | Scale -> 0 | Confidence Score -> [1.26260765]
# Detection:: Location -> (510, 60) | Scale -> 0 | Confidence Score -> [1.23945856]
# Detection:: Location -> (540, 60) | Scale -> 0 | Confidence Score -> [1.78061861]
# Detection:: Location -> (570, 60) | Scale -> 0 | Confidence Score -> [1.71647824]
# Detection:: Location -> (600, 60) | Scale -> 0 | Confidence Score -> [1.88217342]
# Detection:: Location -> (630, 60) | Scale -> 0 | Confidence Score -> [1.72412559]
# Detection:: Location -> (660, 60) | Scale -> 0 | Confidence Score -> [1.92829362]
# Detection:: Location -> (690, 60) | Scale -> 0 | Confidence Score -> [1.54118693]
# Detection:: Location -> (720, 60) | Scale -> 0 | Confidence Score -> [1.9590913]
# Detection:: Location -> (750, 60) | Scale -> 0 | Confidence Score -> [1.82810248]
# Detection:: Location -> (780, 60) | Scale -> 0 | Confidence Score -> [1.61616181]
# Detection:: Location -> (810, 60) | Scale -> 0 | Confidence Score -> [1.66423203]
# Detection:: Location -> (840, 60) | Scale -> 0 | Confidence Score -> [1.42932435]
# Detection:: Location -> (870, 60) | Scale -> 0 | Confidence Score -> [1.55127225]
# Detection:: Location -> (0, 90) | Scale -> 0 | Confidence Score -> [1.20560974]
# Detection:: Location -> (30, 90) | Scale -> 0 | Confidence Score -> [1.45431051]
# Detection:: Location -> (60, 90) | Scale -> 0 | Confidence Score -> [1.40219236]
# Detection:: Location -> (90, 90) | Scale -> 0 | Confidence Score -> [1.07757412]
# Detection:: Location -> (120, 90) | Scale -> 0 | Confidence Score -> [1.37943079]
# Detection:: Location -> (150, 90) | Scale -> 0 | Confidence Score -> [1.37809994]
# Detection:: Location -> (180, 90) | Scale -> 0 | Confidence Score -> [1.64303228]
# Detection:: Location -> (210, 90) | Scale -> 0 | Confidence Score -> [1.45106358]
# Detection:: Location -> (240, 90) | Scale -> 0 | Confidence Score -> [1.70961173]
# Detection:: Location -> (270, 90) | Scale -> 0 | Confidence Score -> [1.5887902]
# Detection:: Location -> (300, 90) | Scale -> 0 | Confidence Score -> [1.38770049]
# Detection:: Location -> (330, 90) | Scale -> 0 | Confidence Score -> [1.67104281]
# Detection:: Location -> (360, 90) | Scale -> 0 | Confidence Score -> [1.68539858]
# Detection:: Location -> (390, 90) | Scale -> 0 | Confidence Score -> [1.66737665]
# Detection:: Location -> (420, 90) | Scale -> 0 | Confidence Score -> [1.23234667]
# Detection:: Location -> (450, 90) | Scale -> 0 | Confidence Score -> [1.5944106]
# Detection:: Location -> (480, 90) | Scale -> 0 | Confidence Score -> [1.51380908]
# Detection:: Location -> (510, 90) | Scale -> 0 | Confidence Score -> [1.31482064]
# Detection:: Location -> (540, 90) | Scale -> 0 | Confidence Score -> [1.420303]
# Detection:: Location -> (570, 90) | Scale -> 0 | Confidence Score -> [1.69919403]
# Detection:: Location -> (600, 90) | Scale -> 0 | Confidence Score -> [1.6480467]
# Detection:: Location -> (630, 90) | Scale -> 0 | Confidence Score -> [1.75884377]
# Detection:: Location -> (660, 90) | Scale -> 0 | Confidence Score -> [1.8962564]
# Detection:: Location -> (690, 90) | Scale -> 0 | Confidence Score -> [1.8302681]
# Detection:: Location -> (720, 90) | Scale -> 0 | Confidence Score -> [1.76574506]
# Detection:: Location -> (750, 90) | Scale -> 0 | Confidence Score -> [1.83916224]
# Detection:: Location -> (780, 90) | Scale -> 0 | Confidence Score -> [1.9539722]
# Detection:: Location -> (810, 90) | Scale -> 0 | Confidence Score -> [1.83538562]
# Detection:: Location -> (840, 90) | Scale -> 0 | Confidence Score -> [1.54781767]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 filename = "D:/UGM/Semester 4/Computer Vision and Image Analysis/Final Project/dataset/raw/IMG_2392.jpg"
# ----> 2 detector(filename)
#
# Cell In[19], line 50, in detector(filename)
#      48     if pred == 1:
#      49         print('Detection:: Location -> ({}, {}) | Scale -> {} | Confidence Score -> {}'.format(x, y, scale, clf.decision_function(combined_features)))
# ---> 50         if clf.decision_function(combined_features) > 0.5:
#      51             detections.append((int(x * (downscale**scale)),
#      52                                int(y * (downscale**scale)),
#      53                                clf.decision_function(combined_features),
#      54                                int(min_window_size[0] * (downscale**scale)),
#      55                                int(min_window_size[1] * (downscale**scale))))
#      57 scale += 1
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:779, in BaseSVC.decision_function(self, X)
#     752 def decision_function(self, X):
#     753     """Evaluate the decision function for the samples in X.
#     754
#     755     Parameters
#    (...)
#     777     transformation of ovo decision function.
#     778     """
# --> 779     dec = self._decision_function(X)
#     780     if self.decision_function_shape == "ovr" and len(self.classes_) > 2:
#     781         return _ovr_decision_function(dec < 0, -dec, len(self.classes_))
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:535, in BaseLibSVM._decision_function(self, X)
#     533     dec_func = self._sparse_decision_function(X)
#     534 else:
# --> 535     dec_func = self._dense_decision_function(X)
#     537 # In binary case, we need to flip the sign of coef, intercept and
#     538 # decision function.
#     539 if self._impl in ["c_svc", "nu_svc"] and len(self.classes_) == 2:
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:551, in BaseLibSVM._dense_decision_function(self, X)
#     548 if callable(kernel):
#     549     kernel = "precomputed"
# --> 551 return libsvm.decision_function(
#     552     X,
#     553     self.support_,
#     554     self.support_vectors_,
#     555     self._n_support,
#     556     self._dual_coef_,
#     557     self._intercept_,
#     558     self._probA,
#     559     self._probB,
#     560     svm_type=LIBSVM_IMPL.index(self._impl),
#     561     kernel=kernel,
#     562     degree=self.degree,
#     563     cache_size=self.cache_size,
#     564     coef0=self.coef0,
#     565     gamma=self._gamma,
#     566 )
#
# KeyboardInterrupt:
